# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
item = pd.read_excel('Assignment-6.xls')
user = pd.read_excel('Assignment-6.xls', sheetname='Users')

# %%
item = item.drop(1, axis=0)

# %%
item.head()
# Out:
#     1                                          2           3           4   \
# 0  NaN                                     Weight  203.615022  121.021257
# 2   11  Star Wars: Episode IV - A New Hope (1977)   -0.106651   -0.094401
# 3   12                        Finding Nemo (2003)   -0.023980   -0.026960
# 4   13                        Forrest Gump (1994)   -0.157042   -0.039889
# 5   14                     American Beauty (1999)   -0.044468    0.198715
#
#            5          6          7          8          9          10  \
# 0  102.797882  96.830823  85.133738  82.763808  79.835000  77.666420
# 2    0.199949   0.025196  -0.064437   0.276259  -0.206928   0.054093
# 3   -0.038067   0.248296  -0.118894  -0.068092   0.064117   0.037390
# 4   -0.224400   0.062452   0.098026   0.078255  -0.047104   0.147743
# 5   -0.006577   0.008760   0.056093  -0.020370  -0.046150   0.007244
#
#           11         12         13         14         15         16         17
# ...

# %%
user[user['User'] == 4469]
# Out:
#    User         1         2         3         4         5         6         7  \
# 8  4469 -0.002139 -0.001049 -0.004224 -0.001461  0.003396  0.001352 -0.000004
#
#           8         9        10        11        12        13        14  \
# 8 -0.001165 -0.000785 -0.002333 -0.001737  0.001324  0.002993  0.000662
#
#          15
# 8 -0.001001

# %%
mm = []
for i in range(2, item.shape[0] + 1):
    summ = 0.0
    for j in range(0, 15):
        tmp = float(user[user['User'] == 4469][1+j]) * float(item[3+j][i]) * float(item[3+j][0])
        summ += tmp
    mm.append((float(summ), int(item[1][i])))

# %%
mm.sort(reverse=True)

# %%
mm
# Out:
# [(0.20767971108623426, 278),
#  (0.18328561173816088, 453),
#  (0.1736114839274811, 98),
#  (0.17217960701329643, 238),
#  (0.1707442935170453, 13),
#  (0.15858945230947022, 424),
#  (0.15478599053855305, 197),
#  (0.14557683890981707, 155),
#  (0.14043305623401078, 597),
#  (0.12219156998210408, 857),
#  (0.10909540822266749, 1422),
#  (0.09600382594658505, 550),
#  (0.08733538111254445, 640),
#  (0.08542113095738879, 274),
#  (0.07353497716918021, 8358),
#  (0.07251301533626141, 272),
#  (0.0658113582292267, 2024),
#  (0.06504894802788827, 1894),
#  (0.06051124047925628, 807),
#  (0.06015853686359816, 2501),
#  (0.05818517690453273, 2502),
#  (0.05670794628885661, 8587),
#  (0.051692762348765346, 745),
#  (0.05167940757106855, 581),
#  (0.04844849806105375, 680),
#  (0.041188587548414216, 122),
#  (0.03858908757767805, 161),
#  (0.03771256148763022, 629),
#  (0.034110181949079374, 77),
#  (0.03354000885463927, 11),
#  (0.03226387651676011, 752),
#  (0.02991458402601721, 603),
# ...
